# %%
print("test")
# Out:
# test

# %%
myTuple = (4,53,2,"barack")

# %%
myTuple
# Out:
# (4, 53, 2, 'barack')

# %%
myTuple[3]
# Out:
# 'barack'

# %%
#test comment
# Out:
#   File "<ipython-input-6-7ed558a2a6be>", line 1
#     test comment
#                ^
# SyntaxError: invalid syntax

# %%
test_comment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-9316ea0f478b> in <module>
# ----> 1 test_comment
#
# NameError: name 'test_comment' is not defined

# %%
#testcomment

# %%
dic = {"mom":2,"bri":18,"dre":23,"dad":57}

# %%
"mom"
# Out:
# 'mom'

# %%
dic["mom"]
# Out:
# 2

# %%
dic.values()
# Out:
# dict_values([2, 18, 23, 57])

# %%
a =range(190,200)

# %%
a
# Out:
# range(190, 200)

# %%
a - 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-e1b46a2f7183> in <module>
# ----> 1 a - 1
#
# TypeError: unsupported operand type(s) for -: 'range' and 'int'

# %%
x = 0
for i in a:
    x+=1

# %%
x
# Out:
# 10

# %%
File1 = open("C:/Users/fabri/OneDrive/Documents/DasText/closerLyrics.txt","r")

# %%
File1.name
# Out:
# 'C:/Users/fabri/OneDrive/Documents/DasText/closerLyrics.txt'

# %%
File1.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-6cc69e4a7405> in <module>
# ----> 1 File1.name
#
# AttributeError: 'tuple' object has no attribute 'name'

# %%
help(File1)
# Out:
# Help on tuple object:
#
# class tuple(object)
#  |  tuple(iterable=(), /)
#  |
#  |  Built-in immutable sequence.
#  |
#  |  If no argument is given, the constructor returns an empty tuple.
#  |  If iterable is specified the tuple is initialized from iterable's items.
#  |
#  |  If the argument is a tuple, the return value is the same object.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, key, /)
#  |      Return self[key].
#  |
#  |  __getnewargs__(self, /)
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __hash__(self, /)
#  |      Return hash(self).
#  |
#  |  __iter__(self, /)
# ...

# %%
File1.name
# Out:
# 'C:/Users/fabri/OneDrive/Documents/DasText/closerLyrics.txt'

# %%
File1.mode
# Out:
# 'r'

# %%
File1.close()

# %%
print(File1.close())
# Out:
# None

# %%
print(File1.close)
# Out:
# <built-in method close of _io.TextIOWrapper object at 0x0000019CD15EB9E8>

# %%
print(File1.closed)
# Out:
# True

# %%
with open("C:/Users/fabri/OneDrive/Documents/DasText/closerLyrics.txt","r") as File:
    lyrics = File.read()
print(File.closed)
# Out:
# True

# %%
print(lyrics)
# Out:
# Hey, I was doing just fine before I met you
# I drink too much and that's an issue but I'm okay
# Hey, you tell your friends it was nice to meet them
# But I hope I never see them again
# I know it breaks your heart
# Moved to the city in a broke down car
# And four years, no calls
# Now you're looking pretty in a hotel bar
# And I can't stop
# No, I can't stop
# So baby pull me closer in the backseat of your Rover
# That I know you can't afford
# Bite that tattoo on your shoulder
# Pull the sheets right off the corner
# Of the mattress that you stole
# From your roommate back in Boulder
# We ain't ever getting older
# We ain't ever getting older
# We ain't ever getting older
# You look as good as the day I met you
# I forget just why I left you, I was insane
# Stay and play that Blink-182 song
# That we beat to death in Tucson, okay
# I know it breaks your heart
# Moved to the city in a broke down car
# And four years, no call
# Now I'm looking pretty in a hotel bar
# ...

# %%
lyrics
# Out:
# "Hey, I was doing just fine before I met you\nI drink too much and that's an issue but I'm okay\nHey, you tell your friends it was nice to meet them\nBut I hope I never see them again\nI know it breaks your heart\nMoved to the city in a broke down car\nAnd four years, no calls\nNow you're looking pretty in a hotel bar\nAnd I can't stop\nNo, I can't stop\nSo baby pull me closer in the backseat of your Rover\nThat I know you can't afford\nBite that tattoo on your shoulder\nPull the sheets right off the corner\nOf the mattress that you stole\nFrom your roommate back in Boulder\nWe ain't ever getting older\nWe ain't ever getting older\nWe ain't ever getting older\nYou look as good as the day I met you\nI forget just why I left you, I was insane\nStay and play that Blink-182 song\nThat we beat to death in Tucson, okay\nI know it breaks your heart\nMoved to the city in a broke down car\nAnd four years, no call\nNow I'm looking pretty in a hotel bar\nAnd I can't stop\nNo, I can't stop\nSo b
# ...

# %%
lyrics.split()
# Out:
# ['Hey,',
#  'I',
#  'was',
#  'doing',
#  'just',
#  'fine',
#  'before',
#  'I',
#  'met',
#  'you',
#  'I',
#  'drink',
#  'too',
#  'much',
#  'and',
#  "that's",
#  'an',
#  'issue',
#  'but',
#  "I'm",
#  'okay',
#  'Hey,',
#  'you',
#  'tell',
#  'your',
#  'friends',
#  'it',
#  'was',
#  'nice',
#  'to',
#  'meet',
#  'them',
#  'But',
#  'I',
#  'hope',
#  'I',
#  'never',
#  'see',
#  'them',
#  'again',
#  'I',
#  'know',
#  'it',
#  'breaks',
#  'your',
#  'heart',
#  'Moved',
#  'to',
#  'the',
#  'city',
#  'in',
#  'a',
#  'broke',
#  'down',
#  'car',
#  'And',
#  'four',
#  'years,',
#  'no',
#  'calls',
#  'Now',
#  "you're",
#  'looking',
#  'pretty',
#  'in',
#  'a',
#  'hotel',
#  'bar',
#  'And',
#  'I',
#  "can't",
#  'stop',
#  'No,',
#  'I',
#  "can't",
#  'stop',
#  'So',
#  'baby',
#  'pull',
#  'me',
#  'closer',
#  'in',
#  'the',
#  'backseat',
#  'of',
#  'your',
#  'Rover',
#  'That',
#  'I',
#  'know',
#  'you',
#  "can't",
#  'afford',
#  'Bite',
# ...

# %%
lyrics
# Out:
# "Hey, I was doing just fine before I met you\nI drink too much and that's an issue but I'm okay\nHey, you tell your friends it was nice to meet them\nBut I hope I never see them again\nI know it breaks your heart\nMoved to the city in a broke down car\nAnd four years, no calls\nNow you're looking pretty in a hotel bar\nAnd I can't stop\nNo, I can't stop\nSo baby pull me closer in the backseat of your Rover\nThat I know you can't afford\nBite that tattoo on your shoulder\nPull the sheets right off the corner\nOf the mattress that you stole\nFrom your roommate back in Boulder\nWe ain't ever getting older\nWe ain't ever getting older\nWe ain't ever getting older\nYou look as good as the day I met you\nI forget just why I left you, I was insane\nStay and play that Blink-182 song\nThat we beat to death in Tucson, okay\nI know it breaks your heart\nMoved to the city in a broke down car\nAnd four years, no call\nNow I'm looking pretty in a hotel bar\nAnd I can't stop\nNo, I can't stop\nSo b
# ...

# %%
everyWord = lyrics.split()

# %%
everyWord
# Out:
# ['Hey,',
#  'I',
#  'was',
#  'doing',
#  'just',
#  'fine',
#  'before',
#  'I',
#  'met',
#  'you',
#  'I',
#  'drink',
#  'too',
#  'much',
#  'and',
#  "that's",
#  'an',
#  'issue',
#  'but',
#  "I'm",
#  'okay',
#  'Hey,',
#  'you',
#  'tell',
#  'your',
#  'friends',
#  'it',
#  'was',
#  'nice',
#  'to',
#  'meet',
#  'them',
#  'But',
#  'I',
#  'hope',
#  'I',
#  'never',
#  'see',
#  'them',
#  'again',
#  'I',
#  'know',
#  'it',
#  'breaks',
#  'your',
#  'heart',
#  'Moved',
#  'to',
#  'the',
#  'city',
#  'in',
#  'a',
#  'broke',
#  'down',
#  'car',
#  'And',
#  'four',
#  'years,',
#  'no',
#  'calls',
#  'Now',
#  "you're",
#  'looking',
#  'pretty',
#  'in',
#  'a',
#  'hotel',
#  'bar',
#  'And',
#  'I',
#  "can't",
#  'stop',
#  'No,',
#  'I',
#  "can't",
#  'stop',
#  'So',
#  'baby',
#  'pull',
#  'me',
#  'closer',
#  'in',
#  'the',
#  'backseat',
#  'of',
#  'your',
#  'Rover',
#  'That',
#  'I',
#  'know',
#  'you',
#  "can't",
#  'afford',
#  'Bite',
# ...

# %%
target = 0
for word in everyWord:
    targetWord = 'tattoo'
    if word == targetWord:
        target += 1
print(targetWord+" is said "+str(target)+" times in the song closer")
# Out:
# tattoo is said 3 times in the song closer

# %%
everyLine = lyrics.split("\n")

# %%
print(everyLine)
# Out:
# ['Hey, I was doing just fine before I met you', "I drink too much and that's an issue but I'm okay", 'Hey, you tell your friends it was nice to meet them', 'But I hope I never see them again', 'I know it breaks your heart', 'Moved to the city in a broke down car', 'And four years, no calls', "Now you're looking pretty in a hotel bar", "And I can't stop", "No, I can't stop", 'So baby pull me closer in the backseat of your Rover', "That I know you can't afford", 'Bite that tattoo on your shoulder', 'Pull the sheets right off the corner', 'Of the mattress that you stole', 'From your roommate back in Boulder', "We ain't ever getting older", "We ain't ever getting older", "We ain't ever getting older", 'You look as good as the day I met you', 'I forget just why I left you, I was insane', 'Stay and play that Blink-182 song', 'That we beat to death in Tucson, okay', 'I know it breaks your heart', 'Moved to the city in a broke down car', 'And four years, no call', "Now I'm looking pretty in 
# ...

# %%
for line in lyrics:
    print(line)
# Out:
# H
# e
# y
# ,
#
# I
#
# w
# a
# s
#
# d
# o
# i
# n
# g
#
# j
# u
# s
# t
#
# f
# i
# n
# e
#
# b
# e
# f
# o
# r
# e
#
# I
#
# m
# e
# t
#
# y
# o
# u
#
#
# I
#
# d
# r
# i
# n
# k
#
# t
# o
# o
#
# m
# u
# c
# h
#
# a
# n
# d
#
# t
# h
# a
# t
# '
# s
#
# a
# n
#
# i
# s
# s
# u
# e
#
# b
# u
# t
#
# I
# '
# m
#
# o
# k
# a
# y
#
#
# H
# e
# y
# ,
#
# y
# o
# u
#
# t
# e
# l
# l
#
# y
# o
# u
# r
#
# f
# r
# i
# e
# n
# d
# s
#
# i
# t
#
# w
# a
# s
#
# n
# i
# c
# e
#
# t
# o
#
# m
# e
# e
# t
#
# t
# h
# e
# m
#
#
# B
# u
# t
#
# I
#
# h
# o
# p
# e
#
# I
#
# n
# e
# v
# e
# r
#
# s
# e
# e
#
# t
# h
# e
# m
#
# a
# g
# a
# i
# n
#
#
# I
#
# k
# n
# o
# w
#
# i
# t
#
# b
# r
# e
# a
# k
# s
#
# y
# o
# u
# r
#
# h
# e
# a
# r
# t
#
#
# M
# o
# v
# e
# d
#
# t
# o
#
# t
# h
# e
#
# c
# i
# t
# y
#
# i
# n
#
# a
#
# b
# r
# o
# k
# e
#
# d
# o
# w
# n
#
# c
# a
# r
#
#
# A
# n
# d
#
# f
# o
# u
# r
#
# y
# e
# a
# r
# s
# ,
#
# n
# o
#
# c
# a
# l
# l
# s
#
#
# N
# o
# w
#
# y
# o
# ...

# %%
File = open("C:/Users/fabri/OneDrive/Documents/DasText/closerLyrics.txt","r")

# %%
for line in File:
    print(line)
# Out:
# Hey, I was doing just fine before I met you
#
# I drink too much and that's an issue but I'm okay
#
# Hey, you tell your friends it was nice to meet them
#
# But I hope I never see them again
#
# I know it breaks your heart
#
# Moved to the city in a broke down car
#
# And four years, no calls
#
# Now you're looking pretty in a hotel bar
#
# And I can't stop
#
# No, I can't stop
#
# So baby pull me closer in the backseat of your Rover
#
# That I know you can't afford
#
# Bite that tattoo on your shoulder
#
# Pull the sheets right off the corner
#
# Of the mattress that you stole
#
# From your roommate back in Boulder
#
# We ain't ever getting older
#
# We ain't ever getting older
#
# We ain't ever getting older
#
# You look as good as the day I met you
#
# I forget just why I left you, I was insane
#
# Stay and play that Blink-182 song
#
# That we beat to death in Tucson, okay
#
# I know it breaks your heart
#
# Moved to the city in a broke down car
#
# And four years, no call
#
# ...

# %%
File.close()

# %%
print(File.closed)
# Out:
# True

# %%
file = open("C:/Users/fabri/OneDrive/Documents/DasText/newText.txt","w")

# %%
print(file.read())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-59-094f07845ae3> in <module>
# ----> 1 print(file.read())
#
# UnsupportedOperation: not readable

# %%
print(file)
# Out:
# <_io.TextIOWrapper name='C:/Users/fabri/OneDrive/Documents/DasText/newText.txt' mode='w' encoding='cp1252'>

# %%
print(file.readlines())
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# <ipython-input-61-0e0d21f6848d> in <module>
# ----> 1 print(file.readlines())
#
# UnsupportedOperation: not readable

# %%
file.write("Hello, I am writing using Python\n")
# Out:
# 33

# %%
file.write("Hello, I am writing using Python\n")
# Out:
# 33

# %%
file.close()

# %%
print(file.closed)
# Out:
# True

# %%
lyrics
# Out:
# "Hey, I was doing just fine before I met you\nI drink too much and that's an issue but I'm okay\nHey, you tell your friends it was nice to meet them\nBut I hope I never see them again\nI know it breaks your heart\nMoved to the city in a broke down car\nAnd four years, no calls\nNow you're looking pretty in a hotel bar\nAnd I can't stop\nNo, I can't stop\nSo baby pull me closer in the backseat of your Rover\nThat I know you can't afford\nBite that tattoo on your shoulder\nPull the sheets right off the corner\nOf the mattress that you stole\nFrom your roommate back in Boulder\nWe ain't ever getting older\nWe ain't ever getting older\nWe ain't ever getting older\nYou look as good as the day I met you\nI forget just why I left you, I was insane\nStay and play that Blink-182 song\nThat we beat to death in Tucson, okay\nI know it breaks your heart\nMoved to the city in a broke down car\nAnd four years, no call\nNow I'm looking pretty in a hotel bar\nAnd I can't stop\nNo, I can't stop\nSo b
# ...

# %%
everyLine
# Out:
# ['Hey, I was doing just fine before I met you',
#  "I drink too much and that's an issue but I'm okay",
#  'Hey, you tell your friends it was nice to meet them',
#  'But I hope I never see them again',
#  'I know it breaks your heart',
#  'Moved to the city in a broke down car',
#  'And four years, no calls',
#  "Now you're looking pretty in a hotel bar",
#  "And I can't stop",
#  "No, I can't stop",
#  'So baby pull me closer in the backseat of your Rover',
#  "That I know you can't afford",
#  'Bite that tattoo on your shoulder',
#  'Pull the sheets right off the corner',
#  'Of the mattress that you stole',
#  'From your roommate back in Boulder',
#  "We ain't ever getting older",
#  "We ain't ever getting older",
#  "We ain't ever getting older",
#  'You look as good as the day I met you',
#  'I forget just why I left you, I was insane',
#  'Stay and play that Blink-182 song',
#  'That we beat to death in Tucson, okay',
#  'I know it breaks your heart',
# ...

# %%
with open("C:/Users/fabri/OneDrive/Documents/DasText/newText.txt","w") as file:
    for line in everyLine:
        file.write(line+"\n")

# %% [raw]
# with open("C:/Users/fabri/OneDrive/Documents/DasText/newText.txt","a") as file:
#     file.append("Hello There,\n")
#     file.append("General Kenobe.... TZZzzZZ")

# %%
help(file)
# Out:
# Help on TextIOWrapper object:
#
# class TextIOWrapper(_TextIOBase)
#  |  TextIOWrapper(buffer, encoding=None, errors=None, newline=None, line_buffering=False, write_through=False)
#  |
#  |  Character and line based layer over a BufferedIOBase object, buffer.
#  |
#  |  encoding gives the name of the encoding that the stream will be
#  |  decoded or encoded with. It defaults to locale.getpreferredencoding(False).
#  |
#  |  errors determines the strictness of encoding and decoding (see
#  |  help(codecs.Codec) or the documentation for codecs.register) and
#  |  defaults to "strict".
#  |
#  |  newline controls how line endings are handled. It can be None, '',
#  |  '\n', '\r', and '\r\n'.  It works as follows:
#  |
#  |  * On input, if newline is None, universal newlines mode is
#  |    enabled. Lines in the input can end in '\n', '\r', or '\r\n', and
#  |    these are translated into '\n' before being returned to the
# ...

# %%
with open("C:/Users/fabri/OneDrive/Documents/DasText/newText.txt","a") as file:
    file.write("Hello There,\n")
    file.write("General Kenobe.... TZZzzZZ")

# %%
import pandas

# %%
#loading a csv file

# %%
csvLocMain = "C:/Users/fabri/OneDrive/Documents/DasText/csvFiles"

# %%
csvLocMain
# Out:
# 'C:/Users/fabri/OneDrive/Documents/DasText/csvFiles'

# %%
statesFileLoc = csvLocMain+"/States.csv"

# %%
statesFileLoc
# Out:
# 'C:/Users/fabri/OneDrive/Documents/DasText/csvFiles/States.csv'

# %%
statesDf = pandas.read_csv(statesFileLoc)

# %%
statesDf
# Out:
#      date state  positive  negative  death
# 0     4-2    AK     143.0    4879.0    3.0
# 1     4-2    AL    1233.0    7503.0   32.0
# 2     4-2    AR     643.0    7880.0   12.0
# 3     4-2    AS       0.0      20.0    0.0
# 4     4-2    AZ    1598.0   21111.0   32.0
# ...   ...   ...       ...       ...    ...
# 1536  3-4    OR       3.0      29.0    NaN
# 1537  3-4    SC       0.0       5.0    NaN
# 1538  3-4    TX       1.0       NaN    NaN
# 1539  3-4    WA      39.0       NaN   10.0
# 1540  3-4    WI       1.0      19.0    NaN
#
# [1541 rows x 5 columns]

# %%
statesDf.head()
# Out:
#   date state  positive  negative  death
# 0  4-2    AK     143.0    4879.0    3.0
# 1  4-2    AL    1233.0    7503.0   32.0
# 2  4-2    AR     643.0    7880.0   12.0
# 3  4-2    AS       0.0      20.0    0.0
# 4  4-2    AZ    1598.0   21111.0   32.0

# %%
deathDf = statesDf[['death']]

# %%
deathDf
# Out:
#       death
# 0       3.0
# 1      32.0
# 2      12.0
# 3       0.0
# 4      32.0
# ...     ...
# 1536    NaN
# 1537    NaN
# 1538    NaN
# 1539   10.0
# 1540    NaN
#
# [1541 rows x 1 columns]

# %%
len(statesDf['state'].unique())
# Out:
# 56

# %%
import numpy as np

# %%
x = np.linspace(0,2*np.pi,100)

# %%
x
# Out:
# array([0.        , 0.06346652, 0.12693304, 0.19039955, 0.25386607,
#        0.31733259, 0.38079911, 0.44426563, 0.50773215, 0.57119866,
#        0.63466518, 0.6981317 , 0.76159822, 0.82506474, 0.88853126,
#        0.95199777, 1.01546429, 1.07893081, 1.14239733, 1.20586385,
#        1.26933037, 1.33279688, 1.3962634 , 1.45972992, 1.52319644,
#        1.58666296, 1.65012947, 1.71359599, 1.77706251, 1.84052903,
#        1.90399555, 1.96746207, 2.03092858, 2.0943951 , 2.15786162,
#        2.22132814, 2.28479466, 2.34826118, 2.41172769, 2.47519421,
#        2.53866073, 2.60212725, 2.66559377, 2.72906028, 2.7925268 ,
#        2.85599332, 2.91945984, 2.98292636, 3.04639288, 3.10985939,
#        3.17332591, 3.23679243, 3.30025895, 3.36372547, 3.42719199,
#        3.4906585 , 3.55412502, 3.61759154, 3.68105806, 3.74452458,
#        3.8079911 , 3.87145761, 3.93492413, 3.99839065, 4.06185717,
#        4.12532369, 4.1887902 , 4.25225672, 4.31572324, 4.37918976,
# ...

# %%
y = np.sin(x)

# %%
y
# Out:
# array([ 0.00000000e+00,  6.34239197e-02,  1.26592454e-01,  1.89251244e-01,
#         2.51147987e-01,  3.12033446e-01,  3.71662456e-01,  4.29794912e-01,
#         4.86196736e-01,  5.40640817e-01,  5.92907929e-01,  6.42787610e-01,
#         6.90079011e-01,  7.34591709e-01,  7.76146464e-01,  8.14575952e-01,
#         8.49725430e-01,  8.81453363e-01,  9.09631995e-01,  9.34147860e-01,
#         9.54902241e-01,  9.71811568e-01,  9.84807753e-01,  9.93838464e-01,
#         9.98867339e-01,  9.99874128e-01,  9.96854776e-01,  9.89821442e-01,
#         9.78802446e-01,  9.63842159e-01,  9.45000819e-01,  9.22354294e-01,
#         8.95993774e-01,  8.66025404e-01,  8.32569855e-01,  7.95761841e-01,
#         7.55749574e-01,  7.12694171e-01,  6.66769001e-01,  6.18158986e-01,
#         5.67059864e-01,  5.13677392e-01,  4.58226522e-01,  4.00930535e-01,
#         3.42020143e-01,  2.81732557e-01,  2.20310533e-01,  1.58001396e-01,
# ...

# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
plt.plot(x,y)

# %%
states.Df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-97-47b2161e336d> in <module>
# ----> 1 states.Df.head()
#
# NameError: name 'states' is not defined

# %%
statesDf.head()
# Out:
#   date state  positive  negative  death
# 0  4-2    AK     143.0    4879.0    3.0
# 1  4-2    AL    1233.0    7503.0   32.0
# 2  4-2    AR     643.0    7880.0   12.0
# 3  4-2    AS       0.0      20.0    0.0
# 4  4-2    AZ    1598.0   21111.0   32.0

# %%
statesDf['totalTested'] = statesDf.apply(lambda row: row.positive + row.negative,axis =1)

# %%
statesDf
# Out:
#      date state  positive  negative  death  totalTested
# 0     4-2    AK     143.0    4879.0    3.0       5022.0
# 1     4-2    AL    1233.0    7503.0   32.0       8736.0
# 2     4-2    AR     643.0    7880.0   12.0       8523.0
# 3     4-2    AS       0.0      20.0    0.0         20.0
# 4     4-2    AZ    1598.0   21111.0   32.0      22709.0
# ...   ...   ...       ...       ...    ...          ...
# 1536  3-4    OR       3.0      29.0    NaN         32.0
# 1537  3-4    SC       0.0       5.0    NaN          5.0
# 1538  3-4    TX       1.0       NaN    NaN          NaN
# 1539  3-4    WA      39.0       NaN   10.0          NaN
# 1540  3-4    WI       1.0      19.0    NaN         20.0
#
# [1541 rows x 6 columns]
